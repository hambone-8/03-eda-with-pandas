# %% [markdown]
# # Pandas for Exploratory Data Analysis II
#
# Pandas a very useful Python library for data manipulation and exploration. We have so much more to see!
#
# In this lesson, we'll continue exploring Pandas for EDA. Specifically:
#
# - Identify and handle missing values with Pandas.
# - Implement groupby statements for specific segmented analysis.
# - Use apply functions to clean data with Pandas.
#
# We'll implicitly review many functions from our first Pandas lesson along the way!

# %% [markdown]
# ## Remember the AdventureWorks Cycles Dataset?
# <img align="right" src="http://lh6.ggpht.com/_XjcDyZkJqHg/TPaaRcaysbI/AAAAAAAAAFo/b1U3q-qbTjY/AdventureWorks%20Logo%5B5%5D.png?imgmax=800">
#
# Here's the Production.Product table [data dictionary](https://www.sqldatadictionary.com/AdventureWorks2014/Production.Product.html), which is a description of the fields (columns) in the table (the .csv file we will import below):<br>
# - **ProductID** - Primary key for Product records.
# - **Name** - Name of the product.
# - **ProductNumber** - Unique product identification number.
# - **MakeFlag** - 0 = Product is purchased, 1 = Product is manufactured in-house.
# - **FinishedGoodsFlag** - 0 = Product is not a salable item. 1 = Product is salable.
# - **Color** - Product color.
# - **SafetyStockLevel** - Minimum inventory quantity.
# - **ReorderPoint** - Inventory level that triggers a purchase order or work order.
# - **StandardCost** - Standard cost of the product.
# - **ListPrice** - Selling price.
# - **Size** - Product size.
# - **SizeUnitMeasureCode** - Unit of measure for the Size column.
# - **WeightUnitMeasureCode** - Unit of measure for the Weight column.
# - **DaysToManufacture** - Number of days required to manufacture the product.
# - **ProductLine** - R = Road, M = Mountain, T = Touring, S = Standard
# - **Class** - H = High, M = Medium, L = Low
# - **Style** - W = Womens, M = Mens, U = Universal
# - **ProductSubcategoryID** - Product is a member of this product subcategory. Foreign key to ProductSubCategory.ProductSubCategoryID.
# - **ProductModelID** - Product is a member of this product model. Foreign key to ProductModel.ProductModelID.
# - **SellStartDate** - Date the product was available for sale.
# - **SellEndDate** - Date the product was no longer available for sale.
# - **DiscontinuedDate** - Date the product was discontinued.
# - **rowguid** - ROWGUIDCOL number uniquely identifying the record. Used to support a merge replication sample.
# - **ModifiedDate** - Date and time the record was last updated.

# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd
import numpy as np # used for linear algebra and random sampling

# used for plotting charts within the notebook (instead of a separate window)
# note we haven't imported matplotlib yet. We will be
# %matplotlib inline

# %% [markdown]
# ### Read in the dataset
#
# We are using the `read_csv()` method (and the `\t` separator to specify tab-delimited columns).

# %%
# read in the dataset
prod_df = pd.read_csv('./data/Production.Product.csv', sep='\t')

# %%
# let's check out the first 3 rows again, for old time's sake
prod_df.head(3)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
# 1          2     Bearing Ball       BA-8327         0                  0
# 2          3  BB Ball Bearing       BE-2349         1                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 0   NaN              1000           750           0.0        0.0  ...
# 1   NaN              1000           750           0.0        0.0  ...
# 2   NaN               800           600           0.0        0.0  ...
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
# 1         NaN   NaN   NaN                   NaN             NaN
# 2         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN              NaN
# 1  2008-04-30 00:00:00         NaN              NaN
# 2  2008-04-30 00:00:00         NaN              NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000
# 2  {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}  2014-02-08 10:01:36.827000000
#
# [3 rows x 25 columns]

# %%
# and the number of rows x cols
prod_df.shape
# Out:
# (504, 25)

# %% [markdown]
# ### Reset our index (like last time)
#
# Let's bring our `ProductID` column into the index since it's the PK (primary key) of our table and that's where PKs belong as a best practice.

# %%
# repalace auto-generated index with the ProductID column
prod_df.set_index('ProductID', inplace=True)

# %%
# .info() gives a lot of info about our data, shape, data types and missing values.
prod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 504 entries, 1 to 999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   504 non-null    object
#  1   ProductNumber          504 non-null    object
#  2   MakeFlag               504 non-null    int64
#  3   FinishedGoodsFlag      504 non-null    int64
#  4   Color                  256 non-null    object
#  5   SafetyStockLevel       504 non-null    int64
#  6   ReorderPoint           504 non-null    int64
#  7   StandardCost           504 non-null    float64
#  8   ListPrice              504 non-null    float64
#  9   Size                   211 non-null    object
#  10  SizeUnitMeasureCode    176 non-null    object
#  11  WeightUnitMeasureCode  205 non-null    object
#  12  Weight                 205 non-null    float64
#  13  DaysToManufacture      504 non-null    int64
#  14  ProductLine            278 non-null    object
#  15  Class                  247 non-null    object
#  16  Style                  211 non-null    object
#  17  ProductSubcategoryID   295 non-null    float64
#  18  ProductModelID         295 non-null    float64
#  19  SellStartDate          504 non-null    object
#  20  SellEndDate            98 non-null     object
#  21  DiscontinuedDate       0 non-null      float64
#  22  rowguid                504 non-null    object
#  23  ModifiedDate           504 non-null    object
# dtypes: float64(6), int64(5), object(13)
# memory usage: 98.4+ KB

# %% [markdown]
# ## Handling missing data
#
# Recall missing data is a systemic, challenging problem for data scientists. Imagine conducting a poll, but some of the data gets lost, or you run out of budget and can't complete it! 😮<br><br>
#
# "Handling missing data" itself is a broad topic. We'll focus on two components:
#
# - Using Pandas to identify we have missing data
# - Strategies to fill in missing data (known in the business as `imputing`)
# - Filling in missing data with Pandas

# %% [markdown]
# ### Identifying missing data
#
# Before *handling*, we must identify we're missing data at all!
#
# We have a few ways to explore missing data, and they are reminiscient of our Boolean filters.

# %%
# True when data is missing - The .head() is here for convenience so we aren't displaying all 504 rows.
prod_df.isna().head(8)
# Out:
#             Name  ProductNumber  MakeFlag  FinishedGoodsFlag  Color  \
# ProductID
# 1          False          False     False              False   True
# 2          False          False     False              False   True
# 3          False          False     False              False   True
# 4          False          False     False              False   True
# 316        False          False     False              False   True
# 317        False          False     False              False  False
# 318        False          False     False              False  False
# 319        False          False     False              False  False
#
#            SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  Size  ...  \
# ProductID                                                                 ...
# 1                     False         False         False      False  True  ...
# 2                     False         False         False      False  True  ...
# 3                     False         False         False      False  True  ...
# 4                     False         False         False      False  True  ...
# 316                   False         False         False      False  True  ...
# 317                   False         False         False      False  True  ...
# 318                   False         False         False      False  True  ...
# 319                   False         False         False      False  True  ...
#
#            ProductLine  Class  Style  ProductSubcategoryID  ProductModelID  \
# ProductID
# 1                 True   True   True                  True            True
# 2                 True   True   True                  True            True
# 3                 True   True   True                  True            True
# 4                 True   True   True                  True            True
# 316               True   True   True                  True            True
# 317               True  False   True                  True            True
# 318               True  False   True                  True            True
# 319               True   True   True                  True            True
#
#            SellStartDate  SellEndDate  DiscontinuedDate  rowguid  ModifiedDate
# ProductID
# 1                  False         True              True    False         False
# 2                  False         True              True    False         False
# 3                  False         True              True    False         False
# 4                  False         True              True    False         False
# 316                False         True              True    False         False
# 317                False         True              True    False         False
# 318                False         True              True    False         False
# 319                False         True              True    False         False
#
# [8 rows x 24 columns]

# %% [markdown]
# Now, we may want to see null values in aggregate. We can use `sum()` to sum down a given column

# %%
# here is a quick and dirty way to get a quick count of missing values
prod_df.isna().sum()
# Out:
# Name                       0
# ProductNumber              0
# MakeFlag                   0
# FinishedGoodsFlag          0
# Color                    248
# SafetyStockLevel           0
# ReorderPoint               0
# StandardCost               0
# ListPrice                  0
# Size                     293
# SizeUnitMeasureCode      328
# WeightUnitMeasureCode    299
# Weight                   299
# DaysToManufacture          0
# ProductLine              226
# Class                    257
# Style                    293
# ProductSubcategoryID     209
# ProductModelID           209
# SellStartDate              0
# SellEndDate              406
# DiscontinuedDate         504
# rowguid                    0
# ModifiedDate               0
# dtype: int64

# %%
# to recap we can see how the missing values compares to the non-null values
prod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 504 entries, 1 to 999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   504 non-null    object
#  1   ProductNumber          504 non-null    object
#  2   MakeFlag               504 non-null    int64
#  3   FinishedGoodsFlag      504 non-null    int64
#  4   Color                  256 non-null    object
#  5   SafetyStockLevel       504 non-null    int64
#  6   ReorderPoint           504 non-null    int64
#  7   StandardCost           504 non-null    float64
#  8   ListPrice              504 non-null    float64
#  9   Size                   211 non-null    object
#  10  SizeUnitMeasureCode    176 non-null    object
#  11  WeightUnitMeasureCode  205 non-null    object
#  12  Weight                 205 non-null    float64
#  13  DaysToManufacture      504 non-null    int64
#  14  ProductLine            278 non-null    object
#  15  Class                  247 non-null    object
#  16  Style                  211 non-null    object
#  17  ProductSubcategoryID   295 non-null    float64
#  18  ProductModelID         295 non-null    float64
#  19  SellStartDate          504 non-null    object
#  20  SellEndDate            98 non-null     object
#  21  DiscontinuedDate       0 non-null      float64
#  22  rowguid                504 non-null    object
#  23  ModifiedDate           504 non-null    object
# dtypes: float64(6), int64(5), object(13)
# memory usage: 98.4+ KB

# %% [markdown]
# Look! We've found missing values!
#
# How could this missing data be problematic for our analysis?

# %% [markdown]
# ### Understanding missing data
#
# Finding missing data is the easy part! Determining way to do next is more complicated.
#
# Typically, we are most interested in knowing **why** we are missing data. Once we know what 'type of missingness' we have (the source of missing data), we can proceed effectively.

# %% [markdown]
# Let's first quantify how much data we are missing. Here is another implementation of `prod_df.isna().sum()`, only wrapped with a `DataFrame` and some labels to make it a little more user-friendly:

# %%
# or we can make things pretty as follows
null_df = pd.DataFrame(prod_df.isna().sum(), columns=['Count of Nulls'])
null_df.index.name = 'Column'
null_df.sort_values(['Count of Nulls'], ascending=False)
# Out:
#                        Count of Nulls
# Column
# DiscontinuedDate                  504
# SellEndDate                       406
# SizeUnitMeasureCode               328
# Weight                            299
# WeightUnitMeasureCode             299
# Size                              293
# Style                             293
# Class                             257
# Color                             248
# ProductLine                       226
# ProductModelID                    209
# ProductSubcategoryID              209
# rowguid                             0
# SellStartDate                       0
# Name                                0
# DaysToManufacture                   0
# ProductNumber                       0
# ListPrice                           0
# StandardCost                        0
# ReorderPoint                        0
# SafetyStockLevel                    0
# FinishedGoodsFlag                   0
# MakeFlag                            0
# ModifiedDate                        0

# %% [markdown]
# ### Filling in missing data
#
# How we fill in data depends largely on why it is missing (types of missingness) and what sampling we have available to us.
#
# We may:
#
# - Delete missing data altogether
# - Fill in missing data with:
#     - The average of the column
#     - The median of the column
#     - A computed amount based on other factors
# - Collect more data:
#     - Resample the population
#     - Followup with the authority providing data that is missing

# %% [markdown]
# In our case, let's focus on handling missing values in `Color`. Let's get a count of the unique values in that column. We will need to use the `dropna=False` kwarg, otherwise the `pd.Series.value_counts()` method will not count `NaN` (null) values.

# %%
# let's get a value count with the nulls included
prod_df['Color'].value_counts(dropna=False)
# Out:
# NaN             248
# Black            93
# Silver           43
# Red              38
# Yellow           36
# Blue             26
# Multi             8
# Silver/Black      7
# White             4
# Grey              1
# Name: Color, dtype: int64

# %% [markdown]
# We have 248 nulls!

# %% [markdown]
# Option 1: Drop the missing values.

# %%
# drops rows where any row has a missing value - this does not happen *in place*, so we are not actually dropping
prod_df['Color'].dropna(inplace=False)
# Out:
# ProductID
# 317     Black
# 318     Black
# 319     Black
# 320    Silver
# 321    Silver
#         ...
# 992     Black
# 993     Black
# 997     Black
# 998     Black
# 999     Black
# Name: Color, Length: 256, dtype: object

# %% [markdown]
# **Important!** `pd.DataFrame.dropna()` and `pd.Series.dropna()` are very versatile! Let's look at the docs (Series is similar):
#
# ```python
# Signature: pd.DataFrame.dropna(self, axis=0, how='any', thresh=None, subset=None, inplace=False)
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     .. deprecated:: 0.23.0: Pass tuple or list to drop on multiple
#     axes.
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
#     * 'any' : If any NA values are present, drop that row or column.
#     * 'all' : If all values are NA, drop that row or column.
# thresh : int, optional
#     Require that many non-NA values.
# subset : array-like, optional
#     Labels along other axis to consider, e.g. if you are dropping rows
#     these would be a list of columns to include.
# inplace : bool, default False
#     If True, do operation inplace and return None.
# ```
#
# **how**: This tells us if we want to remove a row if _any_ of the columns have a null, or _all_ of the columns have a null.<br>
# **subset**: We can input an array here, like `['Color', 'Size', 'Weight']`, and it will only consider nulls in those columns. This is very useful!<br>
# **inplace**: This is if you want to mutate (change) the source dataframe. Default is `False`, so it will return a _copy_ of the source dataframe.

# %% [markdown]
# To accomplish the same thing, but implement it on our entire dataframe, we can do the following:

# %%
# drops all nulls from the Color column, but returns the entire dataframe instead of just the Color column
df = prod_df.dropna(how='any', subset=['Color'], inplace=False)
df
# Out:
#                              Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 317                   LL Crankarm       CA-5965         0                  0
# 318                   ML Crankarm       CA-6738         0                  0
# 319                   HL Crankarm       CA-7457         0                  0
# 320               Chainring Bolts       CB-2903         0                  0
# 321                 Chainring Nut       CN-6137         0                  0
# ...                           ...           ...       ...                ...
# 992        Mountain-500 Black, 48    BK-M18B-48         1                  1
# 993        Mountain-500 Black, 52    BK-M18B-52         1                  1
# 997            Road-750 Black, 44    BK-R19B-44         1                  1
# 998            Road-750 Black, 48    BK-R19B-48         1                  1
# 999            Road-750 Black, 52    BK-R19B-52         1                  1
#
#             Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 317         Black               500           375        0.0000       0.00
# 318         Black               500           375        0.0000       0.00
# 319         Black               500           375        0.0000       0.00
# 320        Silver              1000           750        0.0000       0.00
# 321        Silver              1000           750        0.0000       0.00
# ...           ...               ...           ...           ...        ...
# 992         Black               100            75      294.5797     539.99
# 993         Black               100            75      294.5797     539.99
# 997         Black               100            75      343.6496     539.99
# 998         Black               100            75      343.6496     539.99
# 999         Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 317        NaN  ...         NaN    L     NaN                   NaN
# 318        NaN  ...         NaN    M     NaN                   NaN
# 319        NaN  ...         NaN   NaN    NaN                   NaN
# 320        NaN  ...         NaN   NaN    NaN                   NaN
# 321        NaN  ...         NaN   NaN    NaN                   NaN
# ...        ...  ...         ...   ...    ...                   ...
# 992         48  ...          M     L      U                    1.0
# 993         52  ...          M     L      U                    1.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 317                  NaN  2008-04-30 00:00:00         NaN               NaN
# 318                  NaN  2008-04-30 00:00:00         NaN               NaN
# 319                  NaN  2008-04-30 00:00:00         NaN               NaN
# 320                  NaN  2008-04-30 00:00:00         NaN               NaN
# 321                  NaN  2008-04-30 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 992                 23.0  2013-05-30 00:00:00         NaN               NaN
# 993                 23.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 317        {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}
# 318        {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}
# 319        {7D3FD384-4F29-484B-86FA-4206E276FE58}
# 320        {7BE38E48-B7D6-4486-888E-F53C26735101}
# 321        {3314B1D7-EF69-4431-B6DD-DC75268BD5DF}
# ...                                           ...
# 992        {75752E26-A3B6-4264-9B06-F23A4FBDC5A7}
# 993        {69EE3B55-E142-4E4F-AED8-AF02978FBE87}
# 997        {44CE4802-409F-43AB-9B27-CA53421805BE}
# 998        {3DE9A212-1D49-40B6-B10A-F564D981DBDE}
# 999        {AE638923-2B67-4679-B90E-ABBAB17DCA31}
#
#                             ModifiedDate
# ProductID
# 317        2014-02-08 10:01:36.827000000
# 318        2014-02-08 10:01:36.827000000
# 319        2014-02-08 10:01:36.827000000
# 320        2014-02-08 10:01:36.827000000
# 321        2014-02-08 10:01:36.827000000
# ...                                  ...
# 992        2014-02-08 10:01:36.827000000
# 993        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [256 rows x 24 columns]

# %% [markdown]
# Option 2: Fill in missing values

# %% [markdown]
# Traditionally, we fill missing data with a median, average, or mode (most frequently occurring). For `Color`, let's replace the nulls with the string value `NoColor`.
#
# Let's first look at the way we'd do it with a single column, using the `pd.Series.fillna()` method:

# %%
prod_df['Color'].fillna(value='NoColor').head(10)
# Out:
# ProductID
# 1      NoColor
# 2      NoColor
# 3      NoColor
# 4      NoColor
# 316    NoColor
# 317      Black
# 318      Black
# 319      Black
# 320     Silver
# 321     Silver
# Name: Color, dtype: object

# %%
prod_df.head()
# Out:
#                             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                Adjustable Race       AR-5381         0                  0
# 2                   Bearing Ball       BA-8327         0                  0
# 3                BB Ball Bearing       BE-2349         1                  0
# 4          Headset Ball Bearings       BE-2908         0                  0
# 316                        Blade       BL-2036         1                  0
#
#           Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  \
# ProductID
# 1           NaN              1000           750           0.0        0.0  NaN
# 2           NaN              1000           750           0.0        0.0  NaN
# 3           NaN               800           600           0.0        0.0  NaN
# 4           NaN               800           600           0.0        0.0  NaN
# 316         NaN               800           600           0.0        0.0  NaN
#
#            ... ProductLine Class  Style  ProductSubcategoryID ProductModelID  \
# ProductID  ...
# 1          ...         NaN   NaN    NaN                   NaN            NaN
# 2          ...         NaN   NaN    NaN                   NaN            NaN
# 3          ...         NaN   NaN    NaN                   NaN            NaN
# 4          ...         NaN   NaN    NaN                   NaN            NaN
# 316        ...         NaN   NaN    NaN                   NaN            NaN
#
#                  SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1          2008-04-30 00:00:00         NaN               NaN
# 2          2008-04-30 00:00:00         NaN               NaN
# 3          2008-04-30 00:00:00         NaN               NaN
# 4          2008-04-30 00:00:00         NaN               NaN
# 316        2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
#
# [5 rows x 24 columns]

# %% [markdown]
# Now let's see how we'd do it to the whole dataframe, using the `pd.DataFrame.fillna()` method. Notice the similar API between the methods with the `value` kwarg. Good congruent design, pandas development team! The full dataframe is returned, and not just a column.

# %%
prod_df.fillna(value={'Color': 'NoColor'})
# Out:
#                             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1                Adjustable Race       AR-5381         0                  0
# 2                   Bearing Ball       BA-8327         0                  0
# 3                BB Ball Bearing       BE-2349         1                  0
# 4          Headset Ball Bearings       BE-2908         0                  0
# 316                        Blade       BL-2036         1                  0
# ...                          ...           ...       ...                ...
# 995            ML Bottom Bracket       BB-8107         1                  1
# 996            HL Bottom Bracket       BB-9108         1                  1
# 997           Road-750 Black, 44    BK-R19B-44         1                  1
# 998           Road-750 Black, 48    BK-R19B-48         1                  1
# 999           Road-750 Black, 52    BK-R19B-52         1                  1
#
#              Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 1          NoColor              1000           750        0.0000       0.00
# 2          NoColor              1000           750        0.0000       0.00
# 3          NoColor               800           600        0.0000       0.00
# 4          NoColor               800           600        0.0000       0.00
# 316        NoColor               800           600        0.0000       0.00
# ...            ...               ...           ...           ...        ...
# 995        NoColor               500           375       44.9506     101.24
# 996        NoColor               500           375       53.9416     121.49
# 997          Black               100            75      343.6496     539.99
# 998          Black               100            75      343.6496     539.99
# 999          Black               100            75      343.6496     539.99
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 1          NaN  ...         NaN   NaN    NaN                   NaN
# 2          NaN  ...         NaN   NaN    NaN                   NaN
# 3          NaN  ...         NaN   NaN    NaN                   NaN
# 4          NaN  ...         NaN   NaN    NaN                   NaN
# 316        NaN  ...         NaN   NaN    NaN                   NaN
# ...        ...  ...         ...   ...    ...                   ...
# 995        NaN  ...         NaN    M     NaN                   5.0
# 996        NaN  ...         NaN    H     NaN                   5.0
# 997         44  ...          R     L      U                    2.0
# 998         48  ...          R     L      U                    2.0
# 999         52  ...          R     L      U                    2.0
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1                    NaN  2008-04-30 00:00:00         NaN               NaN
# 2                    NaN  2008-04-30 00:00:00         NaN               NaN
# 3                    NaN  2008-04-30 00:00:00         NaN               NaN
# 4                    NaN  2008-04-30 00:00:00         NaN               NaN
# 316                  NaN  2008-04-30 00:00:00         NaN               NaN
# ...                  ...                  ...         ...               ...
# 995                 96.0  2013-05-30 00:00:00         NaN               NaN
# 996                 97.0  2013-05-30 00:00:00         NaN               NaN
# 997                 31.0  2013-05-30 00:00:00         NaN               NaN
# 998                 31.0  2013-05-30 00:00:00         NaN               NaN
# 999                 31.0  2013-05-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 4          {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 316        {E73E9750-603B-4131-89F5-3DD15ED5FF80}
# ...                                           ...
# 995        {71AB847F-D091-42D6-B735-7B0C2D82FC84}
# 996        {230C47C5-08B2-4CE3-B706-69C0BDD62965}
# 997        {44CE4802-409F-43AB-9B27-CA53421805BE}
# 998        {3DE9A212-1D49-40B6-B10A-F564D981DBDE}
# 999        {AE638923-2B67-4679-B90E-ABBAB17DCA31}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
# 4          2014-02-08 10:01:36.827000000
# 316        2014-02-08 10:01:36.827000000
# ...                                  ...
# 995        2014-02-08 10:01:36.827000000
# 996        2014-02-08 10:01:36.827000000
# 997        2014-02-08 10:01:36.827000000
# 998        2014-02-08 10:01:36.827000000
# 999        2014-02-08 10:01:36.827000000
#
# [504 rows x 24 columns]

# %% [markdown]
# But wait! There's more! We can reference any other data or formulas we want with the imputation (the value we fill the nulls with). This is very handy if you want to impute with the average or median of that column... or even another column altogether! Here is an example where we will replace the nulls of `Color` with the average value from the `ListPrice` column. This has no practical value in this application, but immense value in other applications.

# %%
df = prod_df.fillna(value={'Color': prod_df['ListPrice'].mean()}).head(3)

# %%
df
# Out:
#                       Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# ProductID
# 1          Adjustable Race       AR-5381         0                  0
# 2             Bearing Ball       BA-8327         0                  0
# 3          BB Ball Bearing       BE-2349         1                  0
#
#                Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  \
# ProductID
# 1          438.66625              1000           750           0.0        0.0
# 2          438.66625              1000           750           0.0        0.0
# 3          438.66625               800           600           0.0        0.0
#
#           Size  ... ProductLine Class  Style  ProductSubcategoryID  \
# ProductID       ...
# 1          NaN  ...         NaN   NaN    NaN                   NaN
# 2          NaN  ...         NaN   NaN    NaN                   NaN
# 3          NaN  ...         NaN   NaN    NaN                   NaN
#
#           ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# ProductID
# 1                    NaN  2008-04-30 00:00:00         NaN               NaN
# 2                    NaN  2008-04-30 00:00:00         NaN               NaN
# 3                    NaN  2008-04-30 00:00:00         NaN               NaN
#
#                                           rowguid  \
# ProductID
# 1          {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 2          {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 3          {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
#
#                             ModifiedDate
# ProductID
# 1          2014-02-08 10:01:36.827000000
# 2          2014-02-08 10:01:36.827000000
# 3          2014-02-08 10:01:36.827000000
#
# [3 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 1 to 3
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   3 non-null      object
#  1   ProductNumber          3 non-null      object
#  2   MakeFlag               3 non-null      int64
#  3   FinishedGoodsFlag      3 non-null      int64
#  4   Color                  3 non-null      object
#  5   SafetyStockLevel       3 non-null      int64
#  6   ReorderPoint           3 non-null      int64
#  7   StandardCost           3 non-null      float64
#  8   ListPrice              3 non-null      float64
#  9   Size                   0 non-null      object
#  10  SizeUnitMeasureCode    0 non-null      object
#  11  WeightUnitMeasureCode  0 non-null      object
#  12  Weight                 0 non-null      float64
#  13  DaysToManufacture      3 non-null      int64
#  14  ProductLine            0 non-null      object
#  15  Class                  0 non-null      object
#  16  Style                  0 non-null      object
#  17  ProductSubcategoryID   0 non-null      float64
#  18  ProductModelID         0 non-null      float64
#  19  SellStartDate          3 non-null      object
#  20  SellEndDate            0 non-null      object
#  21  DiscontinuedDate       0 non-null      float64
#  22  rowguid                3 non-null      object
#  23  ModifiedDate           3 non-null      object
# dtypes: float64(6), int64(5), object(13)
# memory usage: 600.0+ bytes

# %% [markdown]
# They're gone! Important points:
#
# - Don't forget to use the `inplace=True` argument to mutate the source dataframe (i.e. 'save changes').
# - It is helpful to not use `inplace=True` initially to ensure your code/logic is correct, prior to making permanent changes.

# %% [markdown]
# ### Exercise
# Replace the null values in ```ProductLine``` with ```"NoProdLine"```

# %%
# answer here

# %% [markdown]
# ## Groupby Statements
#
# In Pandas, groupby statements are similar to pivot tables in that they allow us to segment our population to a specific subset.
#
# For example, if we want to know the average number of bottles sold and pack sizes per city, a groupby statement would make this task much more straightforward.

# %% [markdown]
# To think how a groupby statement works, think about it like this:
#
# - **Split:** Separate our DataFrame by a specific attribute, for example, group by `Color`
# - **Combine:** Put our DataFrame back together and return some _aggregated_ metric, such as the `sum`, `count`, or `max`.

# %% [markdown]
# ![](http://i.imgur.com/yjNkiwL.png)

# %% [markdown]
# Let's try it out!

# %% [markdown]
# Let's group by `Color`, and get a count of products for each color.

# %%
# group by Color, giving the number of products of each %color
prod_df.groupby(by=['Color']).count().reset_index()
# Out:
#           Color  Name  ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0         Black    93             93        93                 93
# 1          Blue    26             26        26                 26
# 2          Grey     1              1         1                  1
# 3         Multi     8              8         8                  8
# 4           Red    38             38        38                 38
# 5        Silver    43             43        43                 43
# 6  Silver/Black     7              7         7                  7
# 7         White     4              4         4                  4
# 8        Yellow    36             36        36                 36
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  Size  ...  \
# 0                93            93            93         93    71  ...
# 1                26            26            26         26    25  ...
# 2                 1             1             1          1     0  ...
# 3                 8             8             8          8     7  ...
# 4                38            38            38         38    37  ...
# 5                43            43            43         43    31  ...
# 6                 7             7             7          7     0  ...
# 7                 4             4             4          4     4  ...
# 8                36            36            36         36    36  ...
#
#    ProductLine  Class  Style  ProductSubcategoryID  ProductModelID  \
# 0           86     72     71                    89              89
# 1           26     22     25                    26              26
# 2            1      0      0                     1               1
# 3            8      0      8                     8               8
# 4           38     37     37                    38              38
# 5           31     30     30                    36              36
# 6            7      6      0                     7               7
# 7            4      0      4                     4               4
# 8           36     32     36                    36              36
#
#    SellStartDate  SellEndDate  DiscontinuedDate  rowguid  ModifiedDate
# 0             93           44                 0       93            93
# 1             26            0                 0       26            26
# 2              1            1                 0        1             1
# 3              8            3                 0        8             8
# 4             38           30                 0       38            38
# 5             43            6                 0       43            43
# 6              7            0                 0        7             7
# 7              4            2                 0        4             4
# 8             36            0                 0       36            36
#
# [9 rows x 24 columns]

# %% [markdown]
# What do we notice about this output? Are all columns the same? Why or why not?
#
# We can see that the `.count()` method excludes nulls, and there is no way to change this with the current implementation:
# ```python
# Signature: .count()
# Docstring: Compute count of group, excluding missing values
# File:      ~/miniconda3/envs/ga/lib/python3.7/site-packages/pandas/core/groupby/groupby.py
# Type:      method
# ```
#
# As a best practice, you should either:
# - fill in nulls prior to your .count(), or
# - use the PK (primary key) of the table, which is guaranteed non-null

# %%
# here we can use 'x' as a dummy placeholder for nulls, simply to get consistent counts for all columns
prod_df.fillna(value={'Color': 'NoColor'}).groupby('Color', as_index=False).count()
# Out:
#           Color  Name  ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0         Black    93             93        93                 93
# 1          Blue    26             26        26                 26
# 2          Grey     1              1         1                  1
# 3         Multi     8              8         8                  8
# 4       NoColor   248            248       248                248
# 5           Red    38             38        38                 38
# 6        Silver    43             43        43                 43
# 7  Silver/Black     7              7         7                  7
# 8         White     4              4         4                  4
# 9        Yellow    36             36        36                 36
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  Size  ...  \
# 0                93            93            93         93    71  ...
# 1                26            26            26         26    25  ...
# 2                 1             1             1          1     0  ...
# 3                 8             8             8          8     7  ...
# 4               248           248           248        248     0  ...
# 5                38            38            38         38    37  ...
# 6                43            43            43         43    31  ...
# 7                 7             7             7          7     0  ...
# 8                 4             4             4          4     4  ...
# 9                36            36            36         36    36  ...
#
#    ProductLine  Class  Style  ProductSubcategoryID  ProductModelID  \
# 0           86     72     71                    89              89
# 1           26     22     25                    26              26
# 2            1      0      0                     1               1
# 3            8      0      8                     8               8
# 4           41     48      0                    50              50
# 5           38     37     37                    38              38
# 6           31     30     30                    36              36
# 7            7      6      0                     7               7
# 8            4      0      4                     4               4
# 9           36     32     36                    36              36
#
#    SellStartDate  SellEndDate  DiscontinuedDate  rowguid  ModifiedDate
# 0             93           44                 0       93            93
# 1             26            0                 0       26            26
# 2              1            1                 0        1             1
# 3              8            3                 0        8             8
# 4            248           12                 0      248           248
# 5             38           30                 0       38            38
# 6             43            6                 0       43            43
# 7              7            0                 0        7             7
# 8              4            2                 0        4             4
# 9             36            0                 0       36            36
#
# [10 rows x 24 columns]

# %%
prod_df[['Color', 'ListPrice']].head()
# Out:
#           Color  ListPrice
# ProductID
# 1           NaN        0.0
# 2           NaN        0.0
# 3           NaN        0.0
# 4           NaN        0.0
# 316         NaN        0.0

# %% [markdown]
# Let's find out the most expensive price for an item, by `Color`:

# %%
# Notice we use a list to reference the multiple columns.
prod_df[['Color', 'ListPrice']].groupby(by='Color').max().sort_values('ListPrice', ascending=False).reset_index()

# apply a reset_index() to remove the multi-index
# Out:
#           Color  ListPrice
# 0           Red    3578.27
# 1        Silver    3399.99
# 2         Black    3374.99
# 3          Blue    2384.07
# 4        Yellow    2384.07
# 5          Grey     125.00
# 6         Multi      89.99
# 7  Silver/Black      80.99
# 8         White       9.50

# %% [markdown]
# We can also do multi-level groupbys. This is referred to as a `Multiindex` dataframe. Here, we can see the following fields in a nested group by, with a count of Name (with nulls filled!); effectively giving us a count of the number of products for every unique Class/Style combination:
#
# - Class - H = High, M = Medium, L = Low
# - Style - W = Womens, M = Mens, U = Universal

# %%
df = prod_df.fillna(value={'Name': 'x'}).groupby(by=['Color', 'Style']).count()[['Name']]
df
# Out:
#               Name
# Color  Style
# Black  M         4
#        U        61
#        W         6
# Blue   U        25
# Multi  M         3
#        U         5
# Red    U        37
# Silver U        22
#        W         8
# White  U         4
# Yellow U        22
#        W        14

# %% [markdown]
# #### Aggregating Method
# ```df.groupby('<grouping column>').agg({'<aggregating column>':'<aggregating function>'})```
#
# The other form is:
# ```df.groupby('<grouping column>').agg({ [<aggregating function>] })```
#
#
# We can also use the `.agg()` method with multiple arguments, to simulate a `.describe()` method like we used before:

# %%
prod_df.groupby(by=['Color'])['ListPrice',  'StandardCost'].agg(['count', 'mean', 'min', 'max', 'median']).reset_index()
# Out:
# /Users/bar/dev/miniconda/envs/ga/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#           Color ListPrice                                          \
#                     count         mean     min      max    median
# 0         Black        93   725.121075    0.00  3374.99   337.220
# 1          Blue        26   923.679231   34.99  2384.07   742.350
# 2          Grey         1   125.000000  125.00   125.00   125.000
# 3         Multi         8    59.865000    8.99    89.99    49.990
# 4           Red        38  1401.950000   34.99  3578.27  1431.500
# 5        Silver        43   850.305349    0.00  3399.99   364.090
# 6  Silver/Black         7    64.018571   40.49    80.99    62.090
# 7         White         4     9.245000    8.99     9.50     9.245
# 8        Yellow        36   959.091389   53.99  2384.07   742.350
#
#   StandardCost
#          count        mean      min        max    median
# 0           93  415.446239   0.0000  1898.0944  185.8193
# 1           26  567.159477  13.0863  1481.9379  461.4448
# 2            1   51.562500  51.5625    51.5625   51.5625
# 3            8   34.031775   6.9223    38.4923   37.8066
# 4           38  858.178055  13.0863  2171.2942  868.6342
# 5           43  466.512751   0.0000  1912.1544  199.3757
# 6            7   28.424286  17.9776    35.9596   27.5680
# 7            4    3.379300   3.3623     3.3963    3.3793
# 8           36  597.434781  41.5723  1481.9379  461.4448

# %%
gb = prod_df.groupby(by=['Color'])['ListPrice', 'StandardCost']
#.agg({'ListPrice': ['mean', 'median', 'var'], 'StandardCost': 'max'}).reset_index()
# Out:
# /Users/bar/dev/miniconda/envs/ga/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
gb

# %%
gb.agg({'ListPrice': ['mean', 'median', 'var'], 'StandardCost': 'max'}).reset_index()
# Out:
#           Color    ListPrice                         StandardCost
#                         mean    median           var          max
# 0         Black   725.121075   337.220  7.529250e+05    1898.0944
# 1          Blue   923.679231   742.350  5.524704e+05    1481.9379
# 2          Grey   125.000000   125.000           NaN      51.5625
# 3         Multi    59.865000    49.990  8.144107e+02      38.4923
# 4           Red  1401.950000  1431.500  1.142357e+06    2171.2942
# 5        Silver   850.305349   364.090  1.083307e+06    1912.1544
# 6  Silver/Black    64.018571    62.090  3.297857e+02      35.9596
# 7         White     9.245000     9.245  8.670000e-02       3.3963
# 8        Yellow   959.091389   742.350  4.741333e+05    1481.9379

# %%
is_black = gb.agg({'ListPrice': ['mean', 'median', 'var'], 'StandardCost': 'max'}).reset_index()['Color'] == 'Black'


gb.agg({'ListPrice': ['mean', 'median', 'var'], 'StandardCost': 'max'}).reset_index()[is_black]
# Out:
#    Color   ListPrice                        StandardCost
#                 mean  median            var          max
# 0  Black  725.121075  337.22  752924.992159    1898.0944

# %%
prod_df.head(2).T
# Out:
# ProductID                                                   1  \
# Name                                          Adjustable Race
# ProductNumber                                         AR-5381
# MakeFlag                                                    0
# FinishedGoodsFlag                                           0
# Color                                                     NaN
# SafetyStockLevel                                         1000
# ReorderPoint                                              750
# StandardCost                                              0.0
# ListPrice                                                 0.0
# Size                                                      NaN
# SizeUnitMeasureCode                                       NaN
# WeightUnitMeasureCode                                     NaN
# Weight                                                    NaN
# DaysToManufacture                                           0
# ProductLine                                               NaN
# Class                                                     NaN
# Style                                                     NaN
# ProductSubcategoryID                                      NaN
# ProductModelID                                            NaN
# SellStartDate                             2008-04-30 00:00:00
# SellEndDate                                               NaN
# DiscontinuedDate                                          NaN
# rowguid                {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# ModifiedDate                    2014-02-08 10:01:36.827000000
#
# ProductID                                                   2
# Name                                             Bearing Ball
# ProductNumber                                         BA-8327
# MakeFlag                                                    0
# FinishedGoodsFlag                                           0
# Color                                                     NaN
# SafetyStockLevel                                         1000
# ReorderPoint                                              750
# StandardCost                                              0.0
# ListPrice                                                 0.0
# Size                                                      NaN
# SizeUnitMeasureCode                                       NaN
# WeightUnitMeasureCode                                     NaN
# Weight                                                    NaN
# DaysToManufacture                                           0
# ProductLine                                               NaN
# Class                                                     NaN
# Style                                                     NaN
# ProductSubcategoryID                                      NaN
# ProductModelID                                            NaN
# SellStartDate                             2008-04-30 00:00:00
# SellEndDate                                               NaN
# DiscontinuedDate                                          NaN
# rowguid                {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# ModifiedDate                    2014-02-08 10:01:36.827000000

# %% [markdown]
# #### Exercise
# Write a groupby statement for at least 3 numerical columns and apply a different aggregation function to each. Be prepared to explain what you did.

# %%
## Groupby 1

# %%
## Groupby 2

# %%
## Groupby 3

# %% [markdown]
# ## Apply functions for column operations
#
# Apply functions allow us to perform a complex operation across an entire columns highly efficiently.

# %% [markdown]
# For example, let's say we want to change our colors from a word, to just a single letter. How would we do that?
#
# The first step is writing a function, with the argument being the value we would receive from each cell in the column. This function will mutate the input, and return the result. This result will then be _applied_ to the source dataframe (if desired).

# %%
# get a list of all unique colors
prod_df['Color'].unique()
# Out:
# array([nan, 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
# create a function to convert colors to letters
def color_to_letter(color):
    """put a docstring here"""
    color_dict = {
        'Black': 'B',
        'Silver': 'S',
        'Red': 'R',
        'White': 'W',
        'Blue': 'L',
        'Multi': 'M',
        'Yellow': 'Y',
        'Grey': 'G',
        'Silver/Black': 'V'
    }
    
    try:
        return color_dict[color]
    except:
        return 'N'
    
assert color_to_letter('Blue') == 'L'

# %%
prod_df['Color'].tail()
# Out:
# ProductID
# 995      NaN
# 996      NaN
# 997    Black
# 998    Black
# 999    Black
# Name: Color, dtype: object

# %% [markdown]
# Now we can _apply_ this function to our `pd.Series` object, returning the result (which we can use to overwrite the source, if we choose).

# %%
prod_df['Color'].apply(color_to_letter).tail()
# Out:
# ProductID
# 995    N
# 996    N
# 997    B
# 998    B
# 999    B
# Name: Color, dtype: object

# %% [markdown]
# The `pd.DataFrame.apply` implementation is similar, however it effectively 'scrolls through' the columns and passes each one sequentially to your function:
#
# ```python
# Objects passed to the function are Series objects whose index is
# either the DataFrame's index (``axis=0``) or the DataFrame's columns
# (``axis=1``).
# ```
#
# It should only be used when you wish to apply the same function to all columns (or rows) of your `pd.DataFrame` object.

# %% [markdown]
# We can also use `pd.Series.apply()` with a **lambda expression**. This is an undeclared function and is commonly used for simple functions within the `.apply()` method. Let's use it to add $100 to our `ListPrice` column. Hey, baby needs new shoes!

# %%
# prior to apply method
prod_df['ListPrice'].tail(10)
# Out:
# ProductID
# 990    539.99
# 991    539.99
# 992    539.99
# 993    539.99
# 994     53.99
# 995    101.24
# 996    121.49
# 997    539.99
# 998    539.99
# 999    539.99
# Name: ListPrice, dtype: float64

# %%
# and now with 100 more dollars!
f = lambda x: x + 100


prod_df['ListPrice_100'] = prod_df['ListPrice'].apply(f)

# %%
prod_df['ListPrice_100'].tail(10)
# Out:
# ProductID
# 990    639.99
# 991    639.99
# 992    639.99
# 993    639.99
# 994    153.99
# 995    201.24
# 996    221.49
# 997    639.99
# 998    639.99
# 999    639.99
# Name: ListPrice_100, dtype: float64

# %%
prod_df['dummy'] = 10

# %%
prod_df.tail()

# %% [markdown]
# Boom! Maybe financing that new boat wasn't such a bad idea after all!

# %% [markdown]
# **Your turn:** Identify one other column where we may want to write a new apply function, or use the one we just created for the purposes of cleaning up our dataset.

# %%
0# identify a column to change

# %%
# write a function to change that column (or columns) note: if using a lambda function, you can leave this blank

# %%
# apply that function across the whole column

# %% [markdown]
# ## Wrap up
#
# We've covered even more useful information! Here are the key takeaways:
#
# - **Missing data** comes in many shapes and sizes. Before deciding how to handle it, we identify it exists. We then derive how the missingness is affecting our dataset, and make a determination about how to fill in values.
#
# ```python
# # pro tip for identifying missing data
# df.isna().sum()
# ```
#
# - **Grouby** statements are particularly useful for a subsection-of-interest analysis. Specifically, zooming in on one condition, and determining relevant statstics.
#
# ```python
# # group by
# df.groupby('column').agg['count', 'mean', 'max', 'min']
# ```
#
# - **Apply functions** help us clean values across an entire DataFrame column. They are *like* a for loop for cleaning, but many times more efficient. They follow a common pattern:
# 1. Write a function that works on a single value
# 2. Test that function on a single value
# 3. Apply that function to a whole column
#
# (The most confusing part of apply functions is that we write them with *a single value* in mind, and then apply them to many single values at once.)
